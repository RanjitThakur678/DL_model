# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head(11)
# Out:
#             id        date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  10/13/2014   221900.0         3       1.00         1180
# 1   6414100192   12/9/2014   538000.0         3       2.25         2570
# 2   5631500400   2/25/2015   180000.0         2       1.00          770
# 3   2487200875   12/9/2014   604000.0         4       3.00         1960
# 4   1954400510   2/18/2015   510000.0         3       2.00         1680
# 5   7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6   1321400060   6/27/2014   257500.0         3       2.25         1715
# 7   2008000270   1/15/2015   291850.0         3       1.50         1060
# 8   2414600126   4/15/2015   229500.0         3       1.00         1780
# 9   3793500160   3/12/2015   323000.0         3       2.50         1890
# 10  1736800520    4/3/2015   662500.0         3       2.50         3560
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
# for continuous var we can choose distplot
plt.figure(figsize=(9,7))

sns.distplot(df['price'])
# Out:
# c:\users\ranjit thakur\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
# bedrooms cant be 1.5 or 2.5 so we are treating it as discrete var so lets choose countplot to view 

sns.countplot(df['bedrooms'])
# Out:
# c:\users\ranjit thakur\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()['price'].sort_values()
# we will try to visualizethe features those are highly correlated with scatterplot
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(y='sqft_living',x='price',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(9,7))
sns.boxplot(y='price',x='bedrooms',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(y='lat',x='long',data=df) # looks similar to king county graph
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(y='lat',x='long',data=df,hue= 'price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
len(df)*0.01
# Out:
# 215.97

# %%
df.sort_values('price',ascending=False).head(20) 

# here its visible that the maxm price is 7 milion and cutt off at 3.6, so e can drop 1% to visualize it better
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
non_top1_perc =  df.sort_values('price',ascending=False).iloc[216:]

# %%
non_top1_perc
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',
                data=non_top1_perc,hue='price',
                palette='RdYlGn',edgecolor=None,alpha=0.2)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
df = df.drop('id',axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['month'] = df['date'].apply(lambda date:date.month)

# %%
df['year'] = df['date'].apply(lambda date:date.year)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
sns.boxplot(x='year',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
sns.boxplot(x='month',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df = df.drop('date',axis=1)

# %%
# May be worth considering to remove this or feature engineer categories from it
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
# could make sense due to scaling, higher should correlate to more value
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
X_test.shape
# Out:
# (6480, 19)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,epochs=560)
# Out:
# Epoch 1/560
# 119/119 [==============================] - 1s 9ms/step - loss: 430244003840.0000 - val_loss: 418937405440.0000
# Epoch 2/560
# 119/119 [==============================] - 0s 3ms/step - loss: 429501120512.0000 - val_loss: 416349356032.0000
# Epoch 3/560
# 119/119 [==============================] - 0s 2ms/step - loss: 419043475456.0000 - val_loss: 392379891712.0000
# Epoch 4/560
# 119/119 [==============================] - 0s 2ms/step - loss: 366410137600.0000 - val_loss: 303897116672.0000
# Epoch 5/560
# 119/119 [==============================] - 0s 2ms/step - loss: 240854679552.0000 - val_loss: 159687147520.0000
# Epoch 6/560
# 119/119 [==============================] - 0s 2ms/step - loss: 124525371392.0000 - val_loss: 98186887168.0000
# Epoch 7/560
# 119/119 [==============================] - 0s 2ms/step - loss: 99389415424.0000 - val_loss: 95009890304.0000
# Epoch 8/560
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss      val_loss
# 0    4.302440e+11  4.189374e+11
# 1    4.295011e+11  4.163494e+11
# 2    4.190435e+11  3.923799e+11
# 3    3.664101e+11  3.038971e+11
# 4    2.408547e+11  1.596871e+11
# ..            ...           ...
# 555  2.440331e+10  2.205754e+10
# 556  2.433074e+10  2.201219e+10
# 557  2.436197e+10  2.202780e+10
# 558  2.432569e+10  2.199012e+10
# 559  2.427302e+10  2.196995e+10
#
# [560 rows x 2 columns]

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
X_test
# Out:
# array([[0.1       , 0.08      , 0.04239917, ..., 0.00887725, 0.63636364,
#         0.        ],
#        [0.3       , 0.36      , 0.17269907, ..., 0.00993734, 0.81818182,
#         0.        ],
#        [0.2       , 0.24      , 0.12512927, ..., 0.00547073, 0.90909091,
#         0.        ],
#        ...,
#        [0.1       , 0.08      , 0.05584281, ..., 0.00506255, 1.        ,
#         0.        ],
#        [0.3       , 0.2       , 0.22233713, ..., 0.00774485, 0.09090909,
#         1.        ],
#        [0.3       , 0.32      , 0.27611169, ..., 0.0196531 , 0.45454545,
#         0.        ]])

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 88359.87894241897

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 148222.64595941076

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8344580035826519

# %%
df['price'].mean()
# Out:
# 540296.5735055795

# %%
df['price'].median()
# Out:
# 450000.0

# %%
# Our predictions
plt.scatter(y_test,predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r')

# %%
errors = y_test.reshape(6480, 1) - predictions

# %%
sns.distplot(errors)
# Out:
# c:\users\ranjit thakur\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.81818182, 0.        ]])

# %%
model.predict(single_house)
# Out:
# array([[298498.44]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# month                10.0000
# year               2014.0000
# Name: 0, dtype: float64

# %% [markdown]
# # NEW_DATA_Calculation

# %%
non_top1_perc =  df.sort_values('price',ascending=False).iloc[180:]

# %%
non_top1_perc
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7693   2150000.0         3       2.75         3470      9610     3.0
# 18753  2150000.0         3       3.50         4660      5500     2.0
# 16706  2140000.0         6       4.00         5110      7128     2.5
# 8436   2140000.0         4       3.75         5150    453895     2.0
# 12174  2140000.0         4       3.25         3860     17820     1.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
sns.distplot(non_top1_perc['price'])
# Out:
# c:\users\ranjit thakur\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
non_top1_perc.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'month', 'year'],
#       dtype='object')

# %%
new_data = non_top1_perc

# %%
new_data
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7693   2150000.0         3       2.75         3470      9610     3.0
# 18753  2150000.0         3       3.50         4660      5500     2.0
# 16706  2140000.0         6       4.00         5110      7128     2.5
# 8436   2140000.0         4       3.75         5150    453895     2.0
# 12174  2140000.0         4       3.25         3860     17820     1.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
X = new_data.drop('price',axis=1).values
y = new_data['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,epochs=560)
# Out:
# Epoch 1/560
# 118/118 [==============================] - 0s 4ms/step - loss: 353583169536.0000 - val_loss: 362666917888.0000
# Epoch 2/560
# 118/118 [==============================] - 0s 2ms/step - loss: 353151746048.0000 - val_loss: 361191211008.0000
# Epoch 3/560
# 118/118 [==============================] - 0s 2ms/step - loss: 347768586240.0000 - val_loss: 348732751872.0000
# Epoch 4/560
# 118/118 [==============================] - 0s 2ms/step - loss: 320747896832.0000 - val_loss: 300432162816.0000
# Epoch 5/560
# 118/118 [==============================] - 0s 2ms/step - loss: 246132539392.0000 - val_loss: 196551737344.0000
# Epoch 6/560
# 118/118 [==============================] - 0s 2ms/step - loss: 134724419584.0000 - val_loss: 90384056320.0000
# Epoch 7/560
# 118/118 [==============================] - 0s 2ms/step - loss: 67643813888.0000 - val_loss: 59679707136.0000
# Epoch 8/560
# ...

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 100120.10547361306

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 150646.0013884704

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7367551451021539

# %%
# Our predictions
plt.scatter(y_test,predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r')

# %%
errors = y_test.reshape(6426, 1) - predictions

# %%
sns.distplot(errors)
# Out:
# c:\users\ranjit thakur\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
single_house
# Out:
# array([[0.0625    , 0.07142857, 0.11172414, 0.00440618, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.11489362,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.215     ,
#         0.16510319, 0.00574235, 0.81818182, 0.        ]])

# %%
model.predict(single_house)
# Out:
# array([[283057.22]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# month                10.0000
# year               2014.0000
# Name: 0, dtype: float64
